# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

from datetime import datetime, date
plt.style.use('ggplot')

# %%
# Loading the Transactions Data from the excel file

trans = pd.read_excel('Raw_data.xlsx' , sheet_name='Transactions')

# %%
# Checking first 5 records from Transactions Data

trans.head(5)
# Out:
#    transaction_id  product_id  customer_id transaction_date  online_order  \
# 0               1           2         2950       2017-02-25           0.0
# 1               2           3         3120       2017-05-21           1.0
# 2               3          37          402       2017-10-16           0.0
# 3               4          88         3135       2017-08-31           0.0
# 4               5          78          787       2017-10-01           1.0
#
#   order_status           brand product_line product_class product_size  \
# 0     Approved           Solex     Standard        medium       medium
# 1     Approved   Trek Bicycles     Standard        medium        large
# 2     Approved      OHM Cycles     Standard           low       medium
# 3     Approved  Norco Bicycles     Standard        medium       medium
# 4     Approved  Giant Bicycles     Standard        medium        large
#
#    list_price  standard_cost  product_first_sold_date
# 0       71.49          53.62                  41245.0
# 1     2091.47         388.92                  41701.0
# 2     1793.43         248.82                  36361.0
# 3     1198.46         381.10                  36145.0
# 4     1765.30         709.48                  42226.0

# %%
# Information of columns and data-types of Transactions Data.

trans.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 13 columns):
# transaction_id             20000 non-null int64
# product_id                 20000 non-null int64
# customer_id                20000 non-null int64
# transaction_date           20000 non-null datetime64[ns]
# online_order               19640 non-null float64
# order_status               20000 non-null object
# brand                      19803 non-null object
# product_line               19803 non-null object
# product_class              19803 non-null object
# product_size               19803 non-null object
# list_price                 20000 non-null float64
# standard_cost              19803 non-null float64
# product_first_sold_date    19803 non-null float64
# dtypes: datetime64[ns](1), float64(4), int64(3), object(5)
# memory usage: 2.0+ MB

# %% [markdown]
# The datatype of <b>product_first_sold_date column is not in datetime format</b>. The data type of this column must be changed from int64 to datetime format.

# %% [markdown]
# ## Total Records

# %%
print("Total records (rows) in the dataset : {}".format(trans.shape[0]))
print("Total columns (features) in the dataset : {}".format(trans.shape[1]))
# Out:
# Total records (rows) in the dataset : 20000
# Total columns (features) in the dataset : 13

# %% [markdown]
# ## Numeric Columns and Non-Numeric Columns

# %%
# select numeric columns
df_numeric = trans.select_dtypes(include=[np.number])
numeric_cols = df_numeric.columns.values
print("The numeric columns are :")
print(numeric_cols)


# select non-numeric columns
df_non_numeric = trans.select_dtypes(exclude=[np.number])
non_numeric_cols = df_non_numeric.columns.values
print("The non-numeric columns are :")
print(non_numeric_cols)
# Out:
# The numeric columns are :
# ['transaction_id' 'product_id' 'customer_id' 'online_order' 'list_price'
#  'standard_cost' 'product_first_sold_date']
# The non-numeric columns are :
# ['transaction_date' 'order_status' 'brand' 'product_line' 'product_class'
#  'product_size']

# %% [markdown]
# ## 1. Missing Values Check

# %% [markdown]
# Checking for the presence of any missing values in the dataset. If missing values are present for a particular feature then depending upon the situation the feature may be either dropped (cases when a major amount of data is missing) or an appropiate value will be imputed in the feature column with missing values.

# %%
# Total number of missing values

trans.isnull().sum()
# Out:
# transaction_id               0
# product_id                   0
# customer_id                  0
# transaction_date             0
# online_order               360
# order_status                 0
# brand                      197
# product_line               197
# product_class              197
# product_size               197
# list_price                   0
# standard_cost              197
# product_first_sold_date    197
# dtype: int64

# %%
# Percentage of missing values

trans.isnull().mean()*100
# Out:
# transaction_id             0.000
# product_id                 0.000
# customer_id                0.000
# transaction_date           0.000
# online_order               1.800
# order_status               0.000
# brand                      0.985
# product_line               0.985
# product_class              0.985
# product_size               0.985
# list_price                 0.000
# standard_cost              0.985
# product_first_sold_date    0.985
# dtype: float64

# %% [markdown]
# Here it is observed that columns like <b>online_order, brand, product_line, product_class , product_size, standard_cost, product_first_sold_date</b> have missing values.

# %% [markdown]
# ### 1.1 Online Order

# %% [markdown]
# <b>Since 1.8 % of the records have online_order data missing we can perform mode imputation for this categorical column.</b>

# %%
trans[trans['online_order'].isnull()]
# Out:
#        transaction_id  product_id  customer_id transaction_date  online_order  \
# 97                 98          49          333       2017-06-23           NaN
# 166               167          90         3177       2017-04-26           NaN
# 169               170           6          404       2017-10-16           NaN
# 250               251          63         1967       2017-04-11           NaN
# 300               301          78         2530       2017-03-24           NaN
# 336               337          82         1615       2017-10-30           NaN
# 342               343          61         1478       2017-03-11           NaN
# 398               399          83         1306       2017-12-18           NaN
# 476               477          73          367       2017-02-12           NaN
# 529               530          62         1202       2017-03-31           NaN
# 558               559          20         3104       2017-03-21           NaN
# 576               577           1          149       2017-05-04           NaN
# 760               761           4         2428       2017-12-20           NaN
# 769               770           4         2414       2017-09-10           NaN
# 843               844          40         3412       2017-07-09           NaN
# 914               915          39         2756       2017-03-16           NaN
# 917               918          35         2281       2017-04-30           NaN
# 1060             1061          63         1342       2017-07-14           NaN
# 1071             1072          36         1505       2017-11-09           NaN
# 1159             1160          73         1722       2017-12-15           NaN
# 1192             1193          71           79       2017-11-17           NaN
# 1200             1201          84         3241       2017-05-25           NaN
# 1354             1355          92         1864       2017-02-28           NaN
# 1361             1362          32         1395       2017-01-27           NaN
# 1371             1372          17         3254       2017-04-19           NaN
# 1381             1382          96         1393       2017-12-29           NaN
# 1523             1524          31         2151       2017-05-05           NaN
# 1552             1553          62          842       2017-10-23           NaN
# 1555             1556          73         2776       2017-10-30           NaN
# 1621             1622           0          736       2017-09-07           NaN
# ...               ...         ...          ...              ...           ...
# 18068           18069          26          788       2017-07-14           NaN
# 18085           18086          48         2813       2017-04-07           NaN
# 18335           18336          95         2958       2017-06-04           NaN
# 18471           18472          81          176       2017-03-06           NaN
# 18501           18502          19         2195       2017-11-02           NaN
# 18606           18607          43         2138       2017-12-01           NaN
# 18624           18625          85         1133       2017-06-17           NaN
# 18689           18690          23         2987       2017-12-13           NaN
# 18711           18712          78          665       2017-09-22           NaN
# 18722           18723          65         1597       2017-11-21           NaN
# 18751           18752          22         2200       2017-10-12           NaN
# 18754           18755          55          403       2017-01-30           NaN
# 18821           18822          30         3464       2017-12-13           NaN
# 18846           18847          57           50       2017-09-20           NaN
# 18982           18983          21          743       2017-01-03           NaN
# 19024           19025          36         1937       2017-08-04           NaN
# 19082           19083          90         1204       2017-12-06           NaN
# 19100           19101           8         2713       2017-10-21           NaN
# 19271           19272          91         3017       2017-07-07           NaN
# 19282           19283          55         1364       2017-08-02           NaN
# 19303           19304          35         1776       2017-08-22           NaN
# 19368           19369          66         3223       2017-12-16           NaN
# 19369           19370          91         1107       2017-09-02           NaN
# 19433           19434          86         1557       2017-03-10           NaN
# 19495           19496           2         3028       2017-11-14           NaN
# 19514           19515          51          690       2017-01-22           NaN
# 19573           19574          18         1735       2017-01-15           NaN
# 19580           19581          49         1933       2017-10-12           NaN
# 19635           19636          98         1389       2017-07-26           NaN
# 19843           19844           3            8       2017-01-28           NaN
#
#       order_status           brand product_line product_class product_size  \
# 97        Approved   Trek Bicycles         Road        medium       medium
# 166       Approved  Norco Bicycles     Standard           low       medium
# 169       Approved      OHM Cycles     Standard          high       medium
# 250       Approved           Solex     Standard        medium       medium
# 300       Approved  Giant Bicycles     Standard        medium        large
# 336       Approved  Norco Bicycles     Standard          high       medium
# 342       Approved  Norco Bicycles     Standard        medium        small
# 398       Approved           Solex      Touring        medium        large
# 476       Approved           Solex     Standard        medium       medium
# 529       Approved           Solex     Standard        medium       medium
# 558       Approved   Trek Bicycles     Standard        medium        small
# 576       Approved  Giant Bicycles     Standard        medium       medium
# 760       Approved  Giant Bicycles     Standard          high       medium
# 769       Approved  Giant Bicycles     Standard          high       medium
# 843       Approved      OHM Cycles     Standard          high       medium
# 914       Approved  Giant Bicycles     Standard        medium        large
# 917       Approved  Giant Bicycles     Standard        medium       medium
# 1060      Approved           Solex     Standard        medium       medium
# 1071      Approved           Solex     Standard           low       medium
# 1159      Approved           Solex     Standard        medium       medium
# 1192      Approved           Solex     Standard          high        large
# 1200      Approved   Trek Bicycles         Road        medium       medium
# 1354      Approved        WeareA2B     Standard        medium        small
# 1361      Approved  Giant Bicycles     Standard          high       medium
# 1371      Approved           Solex     Standard          high       medium
# 1381      Approved        WeareA2B         Road           low        small
# 1523      Approved  Giant Bicycles     Standard        medium       medium
# 1552      Approved           Solex     Standard          high       medium
# 1555      Approved           Solex     Standard        medium       medium
# 1621      Approved        WeareA2B     Standard        medium        small
# ...            ...             ...          ...           ...          ...
# 18068     Approved        WeareA2B     Standard        medium       medium
# 18085     Approved        WeareA2B     Standard        medium       medium
# 18335     Approved  Giant Bicycles     Standard        medium        large
# 18471     Approved  Norco Bicycles     Standard        medium        small
# 18501     Approved      OHM Cycles         Road          high        large
# 18606     Approved  Norco Bicycles     Standard        medium       medium
# 18624     Approved        WeareA2B     Standard        medium       medium
# 18689     Approved  Norco Bicycles     Standard        medium       medium
# 18711     Approved  Giant Bicycles     Standard        medium        large
# 18722     Approved        WeareA2B     Standard        medium       medium
# 18751     Approved        WeareA2B     Standard        medium       medium
# 18754     Approved   Trek Bicycles         Road        medium        large
# 18821     Approved           Solex     Standard          high       medium
# 18846     Approved        WeareA2B      Touring        medium        large
# 18982     Approved           Solex     Standard        medium        large
# 19024     Approved           Solex     Standard           low       medium
# 19082     Approved  Norco Bicycles     Standard           low       medium
# 19100     Approved           Solex         Road        medium        small
# 19271     Approved           Solex     Standard        medium       medium
# 19282     Approved   Trek Bicycles         Road        medium        large
# 19303     Approved   Trek Bicycles     Standard           low       medium
# 19368     Approved  Giant Bicycles         Road           low        small
# 19369     Approved        WeareA2B     Standard           low       medium
# 19433     Approved      OHM Cycles     Standard        medium       medium
# 19495     Approved  Giant Bicycles         Road           low        small
# 19514     Approved      OHM Cycles     Standard          high       medium
# 19573     Approved           Solex     Standard        medium       medium
# 19580     Approved   Trek Bicycles         Road        medium       medium
# 19635     Approved   Trek Bicycles     Standard          high       medium
# 19843     Approved   Trek Bicycles     Standard        medium        large
#
#        list_price  standard_cost  product_first_sold_date
# 97         533.51         400.13                  37823.0
# 166        363.01         290.41                  38482.0
# 169        227.88         136.73                  37838.0
# 250       1483.20          99.59                  42145.0
# 300       1765.30         709.48                  35455.0
# 336       1148.64         689.18                  41533.0
# 342        586.45         521.94                  33429.0
# 398       2083.94         675.03                  38206.0
# 476       1945.43         333.18                  38859.0
# 529        478.16         298.72                  34143.0
# 558       1775.81        1580.47                  33455.0
# 576       1403.50         954.82                  40649.0
# 760       1129.13         677.48                  33549.0
# 769       1129.13         677.48                  38258.0
# 843       1458.17         874.90                  36498.0
# 914       1812.75         582.48                  40336.0
# 917       1403.50         954.82                  42688.0
# 1060      1483.20          99.59                  34996.0
# 1071       945.04         507.58                  40784.0
# 1159      1945.43         333.18                  37499.0
# 1192      1842.92        1105.75                  34996.0
# 1200       290.62         215.14                  38206.0
# 1354      1415.01        1259.36                  37626.0
# 1361      1179.00         707.40                  38482.0
# 1371      1024.66         614.80                  35378.0
# 1381      1172.78        1043.77                  37539.0
# 1523       230.91         173.18                  39031.0
# 1552      1024.66         614.80                  35378.0
# 1555      1945.43         333.18                  37499.0
# 1621       175.89         131.92                  37668.0
# ...           ...            ...                      ...
# 18068     1992.93         762.63                  34115.0
# 18085     1762.96         950.52                  41064.0
# 18335      569.56         528.43                  37874.0
# 18471      586.45         521.94                  33429.0
# 18501       12.01           7.21                  39880.0
# 18606     1555.58         818.01                  37873.0
# 18624      752.64         205.36                  42218.0
# 18689     1198.46         381.10                  41701.0
# 18711     1765.30         709.48                  38193.0
# 18722     1807.45         778.69                  42145.0
# 18751       60.34          45.26                  33455.0
# 18754     1894.19         598.76                  35707.0
# 18821      748.17         448.90                  37337.0
# 18846     1890.39         260.14                  34170.0
# 18982     1071.23         380.74                  34244.0
# 19024      945.04         507.58                  35052.0
# 19082      363.01         290.41                  36367.0
# 19100     1703.52        1516.13                  38216.0
# 19271      100.35          75.26                  36367.0
# 19282     1894.19         598.76                  37823.0
# 19303     1057.51         154.40                  34527.0
# 19368      590.26         525.33                  38647.0
# 19369      642.31         513.85                  41922.0
# 19433      235.63         125.07                  38206.0
# 19495      590.26         525.33                  42710.0
# 19514     2005.66        1203.40                  37823.0
# 19573      575.27         431.45                  41345.0
# 19580      533.51         400.13                  41064.0
# 19635      358.39         215.03                  38002.0
# 19843     2091.47         388.92                  37823.0
#
# [360 rows x 13 columns]

# %%
most_freq_online_mode = trans['online_order'].mode()
most_freq_online_mode
# Out:
# 0    1.0
# dtype: float64

# %% [markdown]
# <b>Since 1 is the most frequent value of online order. We will do a mode imputation on this categorical value.</b>

# %%
trans['online_order'].fillna(1, inplace=True)

# %%
trans['online_order'].isnull().sum()
# Out:
# 0

# %% [markdown]
# Currently there are no missing values for online_order column

# %% [markdown]
# ## 1.2 Brand, Product Line, Product Class, Product Size, Standard Cost, Product First Sold Date

# %% [markdown]
# It is observed that when brand is null then all other column values with missing values viz. 'product_line', 'product_class', 'product_size', 'standard_cost', 'product_first_sold_date' are also null. <b>Also this null values comprise 1 % of the dataset. Hence we can drop these records/rows.</b>

# %%
trans[trans['brand'].isnull()][['brand', 'product_line', 'product_class', 'product_size', 
                                'standard_cost', 'product_first_sold_date']].drop_duplicates()
# Out:
#     brand product_line product_class product_size  standard_cost  \
# 136   NaN          NaN           NaN          NaN            NaN
#
#      product_first_sold_date
# 136                      NaN

# %%
trans[trans['brand'].isnull()][['brand', 'product_line', 'product_class', 'product_size', 
                                'standard_cost', 'product_first_sold_date']].shape[0]
# Out:
# 197

# %%
records_to_drop = trans[trans['brand'].isnull()][['brand', 'product_line', 'product_class', 'product_size', 
                                'standard_cost', 'product_first_sold_date']].index
records_to_drop
# Out:
# Int64Index([  136,   159,   366,   406,   676,   780,  1003,  1130,  1196,
#              1282,
#             ...
#             19045, 19132, 19176, 19196, 19205, 19340, 19383, 19793, 19859,
#             19871],
#            dtype='int64', length=197)

# %%
trans.drop(index=records_to_drop, axis=0, inplace=True)

# %% [markdown]
# <b> Finally there are no Missing values in the transaction dataset.</b>

# %%
trans.isnull().sum()
# Out:
# transaction_id             0
# product_id                 0
# customer_id                0
# transaction_date           0
# online_order               0
# order_status               0
# brand                      0
# product_line               0
# product_class              0
# product_size               0
# list_price                 0
# standard_cost              0
# product_first_sold_date    0
# dtype: int64

# %%
print("Total records after removing Missing Values: {}".format(trans.shape[0]))
# Out:
# Total records after removing Missing Values: 19803

# %% [markdown]
# ## 2. Creating a new feature "Profit"

# %% [markdown]
# <b>The Profit column will be the difference between the list price and the standard price of a product.</b>

# %%
trans['Profit'] = trans['list_price']-trans['standard_cost']

# %%
# Dystribution of the Profit Column

plt.figure(figsize=(20,8))
sns.distplot(trans['Profit'])

# %% [markdown]
# ## 3. Inconsistency Check in Data

# %% [markdown]
# We will check whether there is inconsistent data / typo error data is present in the categorical columns.<br>
# The columns to be checked are <b>'online_order', 'order_status' ,'product_line', 'product_class' , 'product_class' and 'brand'</b>

# %% [markdown]
# ### 3.1 Online Order

# %% [markdown]
# There is <b>no inconsistent data</b> in <b>online_order</b> column.

# %%
trans['online_order'].value_counts()
# Out:
# 1.0    10097
# 0.0     9706
# Name: online_order, dtype: int64

# %% [markdown]
# ### 3.2 Order Status

# %% [markdown]
# There is <b>no inconsistent data</b> in <b>order_status</b> column.

# %%
trans['order_status'].value_counts()
# Out:
# Approved     19625
# Cancelled      178
# Name: order_status, dtype: int64

# %%
trans[['order_status', 'online_order']].drop_duplicates()
# Out:
#     order_status  online_order
# 0       Approved           0.0
# 1       Approved           1.0
# 42     Cancelled           0.0
# 254    Cancelled           1.0

# %% [markdown]
# ### 3.3 Product Line

# %% [markdown]
# There is <b>no inconsistent data</b> in <b>product_line</b> column.

# %%
trans['product_line'].value_counts()
# Out:
# Standard    14176
# Road         3970
# Touring      1234
# Mountain      423
# Name: product_line, dtype: int64

# %% [markdown]
# ### 3.4 Product Class

# %% [markdown]
# There is <b>no inconsistent data</b> in <b>product_class</b> column.

# %%
trans['product_class'].value_counts()
# Out:
# medium    13826
# high       3013
# low        2964
# Name: product_class, dtype: int64

# %% [markdown]
# ### 3.5 Product Size

# %% [markdown]
# There is <b>no inconsistent data</b> in <b>product_size</b> column.

# %%
trans['product_size'].value_counts()
# Out:
# medium    12990
# large      3976
# small      2837
# Name: product_size, dtype: int64

# %% [markdown]
# ### 3.6 Brand

# %% [markdown]
# There is <b>no inconsistent data</b> in <b>brand</b> column.

# %%
trans['brand'].value_counts()
# Out:
# Solex             4253
# Giant Bicycles    3312
# WeareA2B          3295
# OHM Cycles        3043
# Trek Bicycles     2990
# Norco Bicycles    2910
# Name: brand, dtype: int64

# %% [markdown]
# ## 4. Duplication Checks

# %% [markdown]
# We need to ensure that there is no duplication of records in the dataset. This may lead to error in data analysis due to poor data quality. If there are duplicate rows of data then we need to drop such records.<br>For checking for duplicate records we need to firstly remove the primary key column of the dataset then apply drop_duplicates() function provided by Python.

# %%
trans_dedupped = trans.drop('transaction_id', axis=1).drop_duplicates()

print("Number of records after removing customer_id (pk), duplicates : {}".format(trans_dedupped.shape[0]))
print("Number of records in original dataset : {}".format(trans.shape[0]))
# Out:
# Number of records after removing customer_id (pk), duplicates : 19803
# Number of records in original dataset : 19803

# %% [markdown]
# <b>Since both the numbers are same. There are no duplicate records in the dataset</b>

# %% [markdown]
# ## 5. Exporting the Cleaned Transactions Data Set to csv

# %% [markdown]
# Currently the Transactions dataset is clean. Hence we can export the data to a csv to continue our data analysis of Customer Segments by joining it to other tables.

# %%
trans.to_csv('Transactions_Cleaned.csv', index=False)
